# %%
import pandas as pd

df_departments = pd.read_csv('data/departments.csv')
df_dept_emp = pd.read_csv('data/dept_emp.csv')
df_dept_manager = pd.read_csv('data/dept_manager.csv')

df_employees = pd.read_csv('data/employees.csv')
df_salaries = pd.read_csv('data/salaries.csv')
df_titles = pd.read_csv('data/titles.csv')

print('departments.csv contents:')
print(df_departments.head())
print(df_departments.columns)

print('dept_emp.csv contents:')
print(df_dept_emp.head())
print(df_dept_emp.columns)

print('dept_manager.csv contents:')
print(df_dept_manager.head())
print(df_dept_manager.columns)

print('employees.csv contents:')
print(df_employees.head())
print(df_employees.columns)

print('salaries.csv contents:')
print(df_salaries.head())
print(df_salaries.columns)

print('titles.csv contents:')
print(df_titles.head())
print(df_titles.columns)
# Out:
# departments.csv contents:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development
# Index(['dept_no', 'dept_name'], dtype='object')
# dept_emp.csv contents:
#    emp_no dept_no
# 0   10001    d005
# 1   10002    d007
# 2   10003    d004
# 3   10004    d004
# 4   10005    d003
# Index(['emp_no', 'dept_no'], dtype='object')
# dept_manager.csv contents:
#   dept_no  emp_no
# 0    d001  110022
# 1    d001  110039
# 2    d002  110085
# 3    d002  110114
# 4    d003  110183
# Index(['dept_no', 'emp_no'], dtype='object')
# employees.csv contents:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001   7/25/1953    Hideyuki   Zallocco   M   4/28/1990
# 1  475053        e0002  11/18/1954       Byong  Delgrande   F    9/7/1991
# 2   57444        e0002   1/30/1958       Berry       Babb   F   3/21/1992
# ...
